# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\smart\AppData\Local\Temp\ipykernel_28660\1020607637.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#steam_games = pd.read_csv(r"C:\Users\smart\OneDrive\Documents\CS506\games.csv\games.csv")
rawg_data = pd.read_csv(r"C:\Users\smart\OneDrive\Documents\CS506\CS506_Final_Project\game_info.csv\game_info.csv")

# %%
#steam_games = pd.DataFrame(steam_games)
rawg_data = pd.DataFrame(rawg_data)

#steam_games

# %%
# cleaning steam

#steam_clean = steam_games.drop(['Tags', 'Screenshots', 'Developers', 'Publishers'], axis =1)
#steam_clean

# This is the steam data cleaned -- I did not use this file.

# %%
# cleaning rawg

rawg_clean = rawg_data.drop(['website', 'tba', 'metacritic'], axis =1)
rawg_clean = rawg_clean.dropna()
rawg_clean
# Out:
#            id                         slug                          name  \
# 0           1               dgeneration-hd               D/Generation HD
# 1          10                      g-prime         G Prime Into The Rain
# 2         100                 land-sliders                  Land Sliders
# 3        1000                   pixel-gear                    Pixel Gear
# 53      10005  seum-speedrunners-from-hell  SEUM: Speedrunners from Hell
# ...       ...                          ...                           ...
# 473891   9950           infinite-mini-golf            Infinite Mini Golf
# 474039   9964      battle-chasers-nightwar      Battle Chasers: Nightwar
# 474060   9966             dead-by-daylight              Dead by Daylight
# 474134   9973                 dynasty-feud                  Dynasty Feud
# 474366   9995                 the-takeover                  The TakeOver
#
#           released              updated  rating  rating_top  playtime  \
# ...

# %%
print("Sorted by Number Owned")
# This is for observing the data. Changing this won't change what is written in filter_rawg_info.csv

rawg_filtered = rawg_clean[["name", "rating", "playtime","achievements_count",'game_series_count', 'reviews_count']]
# To add any new columns you want to observe, add the column name into the string list above

#rawg_owned = rawg_filtered.sort_values(by=["added_status_owned"], ascending=False)

#rawg_owned
# Out:
# Sorted by Number Owned

# %%
print("Sorted by Rating Count")
rawg_rc = rawg_filtered.sort_values(by=["ratings_count"], ascending=False)

rawg_rc
# Out:
# Sorted by Rating Count
#                                   name  rating  playtime  ratings_count  \
# 245294              Grand Theft Auto V    4.48        69           4289
# 233307        The Witcher 3: Wild Hunt    4.67        50           3939
# 317195                        Portal 2    4.61        11           3613
# 37575                           Portal    4.52         4           3050
# 436923     The Elder Scrolls V: Skyrim    4.42        44           3033
# ...                                ...     ...       ...            ...
# 194292          A Good Life: Simulator    0.00         0              0
# 194293                       Hero Hook    0.00         0              0
# 194295    Ace Detective: Find The Clue    0.00         0              0
# 194298  Billionaire, Inc. - Idle Merge    0.00         0              0
# 225488                       iCrabbing    0.00         0              0
#
#         added_status_owned
# 245294                8298
# ...

# %%
print("Sorted by Playtime")
rawg_playtime = rawg_filtered.sort_values(by=["playtime"], ascending=False)

rawg_playtime
# Out:
# Sorted by Playtime
#                                           name  rating  playtime  \
# 281329                                WWE 2K14    3.44       239
# 324301  Shin Megami Tensei: Persona 3 Portable    4.45       226
# 307055          Metal Gear Solid: Peace Walker    4.15       211
# 325626          METAL GEAR SOLID HD COLLECTION    4.33       178
# 456020                                  ROBLOX    3.03       173
# ...                                        ...     ...       ...
# 190318                        Diabolical Pitch    0.00         0
# 190319                             Rad Trails!    0.00         0
# 190320          Monday Night Monsters Football    0.00         0
# 190322              Wizards Unite for Hogwarts    0.00         0
# 225488                               iCrabbing    0.00         0
#
#         ratings_count  added_status_owned
# 281329             41                 203
# 324301             92                  40
# ...

# %%
print("Sorted by Rating")
rawg_rating = rawg_filtered.sort_values(by=["rating"], ascending=False)

rawg_rating
# Out:
# Sorted by Rating
#                                        name  rating  playtime  ratings_count  \
# 33966   The World Ends with You: Solo Remix    4.86         0              7
# 158411                        Kara no Shojo    4.83         8              6
# 240990                      Persona 5 Royal    4.81         0            118
# 287091        Shovel Knight: Shovel of Hope    4.78         2              9
# 158384      The Witcher 3: Game of the Year    4.77         0            439
# ...                                     ...     ...       ...            ...
# 179424           Dead Ringer: Fear Yourself    0.00         0              1
# 179425                          Little Luca    0.00         0              0
# 179450       Gunpowder on The Teeth: Arcade    0.00         0              1
# 179469           Graceful Explosion Machine    0.00         3              5
# 225488                            iCrabbing    0.00         0              0
#
# ...

# %%
# Writing filtered DF to filtered_rawg_info.csv. This one is NOT sorted by any specific column.

# To alter written data in csv file, add/remove/change strings to the list of column names you're interested in
rawg_filtered_csv = rawg_clean[["id", "name", "rating", "playtime", "ratings_count"]]
no_name = rawg_filtered.drop('name', axis =1)
no_name.to_csv("final_predictors.csv", index=False) 

# Current Columns: id, name, rating, playtime, ratings count, how many owned

rawg_filtered_csv.to_csv("filtered_rawg_info.csv", index=False) # index=False removes row numbers, index=True keeps row numbers

# %%
# Correlation matrix
no_name = rawg_filtered.drop('name', axis =1)
corr = no_name.corr()
no_name.to_csv("rawg_data_cleaned.csv", index= False)
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
